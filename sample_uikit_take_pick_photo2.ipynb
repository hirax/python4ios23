# %% [markdown]
# # 写真やフォトアルバムにアクセスする

# %%
# 必要なモジュールを読み込む
from avfoundation.take_pick_photo import * 
# ライブラリ（フォトライブラリ）から画像を選択する
pick_photolibrary_and_save("_library.jpg")

# %%
from PIL import Image
import numpy as np
from matplotlib import pylab as plt

# ファイルから画像を読み込む
img = np.array( Image.open('_library.jpg') )
# 画像を表示する
plt.figure(figsize=[6,6])
plt.imshow( img )

# %%
#pick_photolibrary_and_save("_library.jpg")

pick_photoalbum_and_save("_album.png")
